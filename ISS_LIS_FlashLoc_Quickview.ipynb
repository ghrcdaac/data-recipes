# %%
# -*- coding: utf-8 -*-

# %% [markdown]
# <br>
#        ISS LIS Lightning Flash Heat Map and Flash Location <br>
#        CSV File<br>
# <br>
#        Decription: This code pulls ISS LIS NetCDF data files <br>
#        from a directory, extracts the flash coordinates from <br>
#        the files and generates a flash heat map plot. This code <br>
#        also compiles all lightning flash locations into a single <br>
#        CSV file, so they may be plotted using other software<br>
# <br>
#        Authors: Amanda Weigel<br>
#        Information and Technology Systems Center (ITSC)<br>
#        University of Alabama in Huntsville<br>
#        <br>
#        Last Edit Date: 02 February 2018<br>
# <br>
#  Import Python packages

# %%
! pip install netCDF4
! pip install numpy
! pip install matplotlib
! pip install basemap

import numpy as np
import glob
from netCDF4 import Dataset
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import csv
from itertools import izip

# Define the file directories

dataDir = 'C:/Users/AWeigel/Documents/ScienceOutreach/Masthead/Masthead_Jan/isslis_swath_0104/' #File path where ISS LIS data are stored
csvfile = "C:/Users/AWeigel/Documents/ScienceOutreach/Masthead/Masthead_Jan/isslis_01042918_flashloc_test.csv" #File path and name of CSV file

#Identify all NetCDF files in the directory

files = glob.glob(dataDir+'*.nc')

#Create empty arrays to populate lightning flash location coordinates 

flash_lat = np.array([]) #latitude
flash_lon = np.array([]) #longitude

# Loop through list of NetCDF files, for each file, extract the lightning flash latidude
# and longitude, and add to the respective empty array (flash_lat and flash_lon)

for i in files:
    datafile = Dataset(i)
    
    flash_lat = np.concatenate([flash_lat,datafile.variables['lightning_flash_lat'][:]]) #add to array
    flash_lon = np.concatenate([flash_lon,datafile.variables['lightning_flash_lon'][:]]) #add to array
    
# Create CSV files of values from the populated flash_lat/lon arrays  

with open(csvfile, 'wb') as myfile:
    writer = csv.writer(myfile)
    writer.writerows(izip(["flash_lat"], ["flash_lon"])) #Define headers in row (izip creates columns)
    writer.writerows(izip(flash_lat,flash_lon)) #Define data rows (izip creates columns)
    
# Create plot of lightning flash location heat map

plt.figure(figsize=((20,20))) #Set plot dimensions
map = Basemap(projection='cyl', lon_0 = 0, resolution='c')
lightning = map.hexbin(flash_lon, flash_lat, gridsize=300,bins='log',cmap='jet',mincnt=1,zorder=10) #Bin flash counts into hexbins using a gridsize of your choice

# Draw geographic boundaries and meridians/parallels

map.drawmapboundary(fill_color='k')
map.fillcontinents(color='grey',lake_color='grey')
map.drawcoastlines(color='white')
map.drawcountries(color='white')
map.drawmeridians(np.arange(0,390,30), labels=[0,0,0,1],fontsize=10, color="lightgray")
map.drawparallels(np.arange(-90,120,30), labels=[1,0,0,0],fontsize=10, color="lightgray")

cbar = map.colorbar(lightning,location='bottom',pad="5%")
cbar.set_label('Flash Count') #Remember to change label

plt.title('ISS LIS Detected Lightning Flash Locations January 4, 2018', fontsize = 18) #Rember to change title

plt.show()
# Out:
# Requirement already satisfied: netCDF4 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.9 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from netCDF4) (1.21.5)
# Requirement already satisfied: cftime in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from netCDF4) (1.6.1)
# Requirement already satisfied: numpy in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (1.21.5)
# Requirement already satisfied: matplotlib in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: cycler>=0.10 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: six>=1.5 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/dgaunt_temp/github/data-recipes/ISS_LIS_FlashLoc_Quickview.ipynb Cell 3 in <cell line: 11>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/dgaunt_temp/github/data-recipes/ISS_LIS_FlashLoc_Quickview.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> from mpl_toolkits.basemap import Basemap
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/dgaunt_temp/github/data-recipes/ISS_LIS_FlashLoc_Quickview.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> import csv
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/dgaunt_temp/github/data-recipes/ISS_LIS_FlashLoc_Quickview.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> from itertools import izip
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/dgaunt_temp/github/data-recipes/ISS_LIS_FlashLoc_Quickview.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> # Define the file directories
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/dgaunt_temp/github/data-recipes/ISS_LIS_FlashLoc_Quickview.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> dataDir = 'C:/Users/AWeigel/Documents/ScienceOutreach/Masthead/Masthead_Jan/isslis_swath_0104/' #File path where ISS LIS data are stored
#
# ImportError: cannot import name 'izip' from 'itertools' (unknown location)
