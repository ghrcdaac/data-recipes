# %% [markdown]
# <br>
#        Infrared Global Geostationary Composite Quick View<br>
# <br>
#        Description: This code generates a PNG image of an Infrared <br>
#                Global Geostationary Composite data file<br>
# <br>
#        Authors: Matthew Smith, Leigh Sinclair<br>
#        Information and Technology Systems Center (ITSC)<br>
#        University of Alabama in Huntsville<br>
# <br>
#        Last Edited: 5 July 2017<br>
# <br>
# <br>
# Import Python packages

# %%
! pip install matplotlib

import sys
import os
import struct
import matplotlib.pyplot as plt
 
# Define the file path to the desired date file 
globir="C:/Users/lsinclair/Desktop/globalIR/globir.17019.0545" #Place path to file here using forward slashes
try:
   IN=open(globir, 'rb')
except:
   print('Error: opening file', globir)
   exit(1)
 
# Read the first 768 bytes of the file containing the header and navigation information
dataOffset=768
header=struct.unpack('<192I', IN.read(768))
 
# Extract the data parameters
lines=header[8]
elements=header[9]
arraySize=lines*elements
format="%4dB" % (arraySize)
dataOffset=header[33]   # offset to data array (bytes)
 
# Read image array into a 1D array
IN.seek(dataOffset)
array=struct.unpack(format, IN.read(arraySize))
IN.close()
 
# Set up 2D array and reshape to 2D array to plot the data
array2D=[]
for n in range(0,lines):
   array2D.append(array[n*elements:(n+1)*elements])
 
# Create a plot of the data. The generated PNG image will save to the same folder where the data file is saved.
fig=plt.imshow(array2D, cmap='gray', interpolation='none')
plt.axis('off')
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)
try:
   plt.savefig(globir+".png", dpi=400, bbox_inches='tight', pad_inches=0)
except:
   print('Error: saving figure to',globir+".png")
   exit(1)
else:
   print('Success, saved to', globir+".png")
plt.close('all')
exit(0)

print("Image created")
# Out:
# Requirement already satisfied: matplotlib in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: numpy>=1.17 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in /home/dgaunt_temp/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Error: opening file C:/Users/lsinclair/Desktop/globalIR/globir.17019.0545
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/dgaunt_temp/github/data-recipes/IR_Global_GeoComp_QuickView_DataRecipe.ipynb Cell 2 in <cell line: 18>()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/dgaunt_temp/github/data-recipes/IR_Global_GeoComp_QuickView_DataRecipe.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> # Read the first 768 bytes of the file containing the header and navigation information
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/dgaunt_temp/github/data-recipes/IR_Global_GeoComp_QuickView_DataRecipe.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> dataOffset=768
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/dgaunt_temp/github/data-recipes/IR_Global_GeoComp_QuickView_DataRecipe.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> header=struct.unpack('<192I', IN.read(768))
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/dgaunt_temp/github/data-recipes/IR_Global_GeoComp_QuickView_DataRecipe.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> # Extract the data parameters
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/dgaunt_temp/github/data-recipes/IR_Global_GeoComp_QuickView_DataRecipe.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> lines=header[8]
#
# NameError: name 'IN' is not defined
